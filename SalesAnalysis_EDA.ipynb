# %% [markdown]
# <h1> <center> PANDAS Material_SALES ANALYSIS

# %% [markdown]
# ___

# %% [markdown]
# <h2> OBJECTIVE

# %% [markdown]
# Upon initial inspection of the data, we can start thinking of some questions about it that we would want to answer.

# %% [markdown]
# ___

# %% [markdown]
# <h4> IMPORTING REQUIRED LIBRARIES

# %%
# Data Manipulation
import pandas as pd

# Data Visualisation
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# <h4> IMPORTING THE DATASET

# %%
# Importing dataset
df=pd.read_csv('H:\databi.csv')
df
# Out:
#      year  week   Material 1   Material 2   Material 3   Material 4  \
# 0    2019     1  1943.998334  3735.989790  1853.997943  1323.999226
# 1    2019     2  2065.999058  4959.994586  1647.998921  1266.999444
# 2    2019     3  2185.998409  5113.989053  1653.998344  1195.999780
# 3    2019     4  2070.997315  5537.982563  1510.998921  1229.999593
# 4    2019     5  2088.997611  4865.984147  1554.998109  1313.999444
# ..    ...   ...          ...          ...          ...          ...
# 100  2020   101  1468.998352  3644.990206  1501.997401   822.999741
# 101  2020   102  1603.998382  2849.994760  1558.996636   866.999421
# 102  2020   103  1601.998774  2510.995184  2359.995837  2345.997258
# 103  2020   104  2356.997346  4677.991632  1813.997045   709.999586
# 104  2020   105  1701.998583  4654.983543  1525.997949  1011.999092
#
#       Material 5
# 0    1257.998631
# 1    1245.999428
# 2    1163.999214
# 3    1234.999626
# 4    1170.999239
# ..           ...
# 100   918.999570
# 101   934.999605
# 102  1220.999334
# 103  1060.998909
# 104   970.999254
#
# [105 rows x 7 columns]

# %% [markdown]
# <H3> DATA AUDIT

# %% [markdown]
# You can’t make your data work for you until you know what data you’re talking about.
#
# To get a quick idea of what the data looks like, we can call the head function on the data frame. By default, this returns the top five rows, but it can take in a parameter of how many rows to return.

# %%
# First five rows of the dataset
df.head()
# Out:
#    year  week   Material 1   Material 2   Material 3   Material 4   Material 5
# 0  2019     1  1943.998334  3735.989790  1853.997943  1323.999226  1257.998631
# 1  2019     2  2065.999058  4959.994586  1647.998921  1266.999444  1245.999428
# 2  2019     3  2185.998409  5113.989053  1653.998344  1195.999780  1163.999214
# 3  2019     4  2070.997315  5537.982563  1510.998921  1229.999593  1234.999626
# 4  2019     5  2088.997611  4865.984147  1554.998109  1313.999444  1170.999239

# %%
# Last five rows of the dataset
df.tail()
# Out:
#      year  week   Material 1   Material 2   Material 3   Material 4  \
# 100  2020   101  1468.998352  3644.990206  1501.997401   822.999741
# 101  2020   102  1603.998382  2849.994760  1558.996636   866.999421
# 102  2020   103  1601.998774  2510.995184  2359.995837  2345.997258
# 103  2020   104  2356.997346  4677.991632  1813.997045   709.999586
# 104  2020   105  1701.998583  4654.983543  1525.997949  1011.999092
#
#       Material 5
# 100   918.999570
# 101   934.999605
# 102  1220.999334
# 103  1060.998909
# 104   970.999254

# %%
# Shape of the dataset
df.shape
# Out:
# (105, 7)

# %%
# Columns present in the dataset
df.columns
# Out:
# Index(['year', 'week', 'Material 1', 'Material 2', 'Material 3', 'Material 4',
#        'Material 5'],
#       dtype='object')

# %% [markdown]
# This looks a lot like an Excel spreadsheet, doesn’t it? Under the hood, the data frame is a two-dimensional data structure and each column can have different types. To show that, we can call dtypes attribute on the data frame to see what each column types are.

# %%
# A concise summary of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        105 non-null    int64
#  1   week        105 non-null    int64
#  2   Material 1  105 non-null    float64
#  3   Material 2  105 non-null    float64
#  4   Material 3  105 non-null    float64
#  5   Material 4  105 non-null    float64
#  6   Material 5  105 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 5.9 KB

# %% [markdown]
# Now we can do further analysis on our data to answer our questions. Before that, we should see if there are any missing values in our data set.To check if there are any missing values in the entire data set we use the isnull function, then see if there are any values.
#
# We’re lucky we have such a nice data set and with no missing values. While we won’t focus on it in this post, a data scientist will spend their time cleaning (or wrangling ) the data. Since we don’t have any missing data, we can start doing further analysis on our data.

# %%
# Checking missing values
df.isna().sum()
# Out:
# year          0
# week          0
# Material 1    0
# Material 2    0
# Material 3    0
# Material 4    0
# Material 5    0
# dtype: int64

# %% [markdown]
# Next, we can look at some descriptive statistics of the data frame with the describe method.
#
# This shows some descriptive statistics on the data set. Notice, it only shows the statistics on the numerical columns. From here you can see the following statistics:
#
# - Row count, which aligns to what the shape attribute showed us.
# - The mean, or average.
# - The standard deviation, or how spread out the data is.
# - The minimum and maximum value of each column
# - The number of items that fall within the first, second, and third percentiles.

# %%
# Generating descriptive statistics summary
df.describe().round()
# Out:
#          year   week  Material 1  Material 2  Material 3  Material 4  \
# count   105.0  105.0       105.0       105.0       105.0       105.0
# mean   2020.0   53.0      3099.0      3670.0      1753.0      1204.0
# std       1.0   30.0      1535.0      2226.0       324.0       342.0
# min    2019.0    1.0      1469.0       582.0       834.0       421.0
# 25%    2019.0   27.0      1997.0      2287.0      1525.0       977.0
# 50%    2020.0   53.0      2357.0      3415.0      1665.0      1237.0
# 75%    2020.0   79.0      3944.0      4655.0      1970.0      1344.0
# max    2020.0  105.0      7928.0     15784.0      2837.0      2964.0
#
#        Material 5
# count       105.0
# mean       1117.0
# std         198.0
# min         455.0
# 25%         978.0
# 50%        1090.0
# 75%        1246.0
# max        1643.0

# %% [markdown]
# <h3> EXPLORATORY DATA ANALYSIS

# %% [markdown]
# - <h4> WHAT IS THE OVERALL SALES TREND?

# %%
# grouping month_year by sales
df1_temp = df.groupby('week').sum()['Material 1'].reset_index()

# %%
# Setting the figure size
plt.figure(figsize=(16, 5))
plt.plot(df_temp['week'], df1_temp['Material 1'], color='#b80045')
plt.xticks(rotation='vertical', size=10)
plt.show()

# %%
# grouping month_year by sales
df2_temp = df.groupby('week').sum()['Material 2'].reset_index()

# %%
# Setting the figure size
plt.figure(figsize=(16, 5))
plt.plot(df1_temp['week'], df2_temp['Material 2'], color='#b80045')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %%
# grouping month_year by sales
df3_temp = df.groupby('week').sum()['Material 3'].reset_index()

# %%
# Setting the figure size
plt.figure(figsize=(16, 5))
plt.plot(df1_temp['week'], df3_temp['Material 3'], color='#b80045')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %%
# grouping month_year by sales
df4_temp = df.groupby('week').sum()['Material 4'].reset_index()

# %%
# Setting the figure size
plt.figure(figsize=(16, 5))
plt.plot(df_temp['week'], df4_temp['Material 4'], color='#b80045')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %%
# grouping month_year by sales
df5_temp = df.groupby('week').sum()['Material 5'].reset_index()

# %%
# Setting the figure size
plt.figure(figsize=(16, 5))
plt.plot(df_temp['week'], df5_temp['Material 5'], color='#b80045')
plt.xticks(rotation='vertical', size=8)
plt.show()
